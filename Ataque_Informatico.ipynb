# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/JuanCarlosRondeau">
# <img src="https://avatars.githubusercontent.com/u/61326801?v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Christian Vlaldimir Sucuzhanay Arevalo 21535220">
# <a href ="https://github.com/JuanCarlosRondeau?tab=repositories">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %% [markdown]
# # Se solicita realizar ataques simultaneos a los siguientes sitios web

# %%
import threading, os, platform, requests, json

# %%
numero_de_veces_hasta_matar_uem = 1

# %%
url_="https://github.com/sukuzhanay"

# %% [markdown]
# # HTTP CODIGOS

# %%
from IPython import display

# %%
display.Image("STATUSCODE.PNG")

# %%
array = ["https://github.com/sukuzhanay","https://rpubs.com/christian_sucuzhanay"]

# %%
def master_uem(url):
    print(requests.get(url))
    threading.current_thread()
    print(requests.get(url).content)

# %%
def descargar(x):
    for i in range(len(x)):
        print(x[i]+":")
        threading.Thread(target=master_uem(x[i])).start()

# %%
descargar(array)
# Out:
# https://github.com/sukuzhanay:
# <Response [200]>
# ...

# %%
res_=requests.get("https://nude-project.com/2537259054/checkouts/760fdfa20b670312f6e6664981b4143b/thank_you")

# %%
res_.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-ES" dir="ltr" class="no-js desktop page--no-banner page--logo-main page--thank-you">\n  <head>\n<script type="text/javascript" src="https://edge.personalizer.io/storefront/2.0.0/js/shopify/storefront.min.js?key=y0zki-ru1kbi3r3on8j3nh3q-imjy8&shop=new-polinesia.myshopify.com"></script>\r\n<script>\r\nwindow.LimeSpot = window.LimeSpot === undefined ? {} : LimeSpot;\r\n\r\nLimeSpot.StoreInfo = { Theme: "" };\r\n\r\n\r\nLimeSpot.CartItems = [];\r\n</script>\r\n\r\n\r\n\r\n\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, height=device-height, minimum-scale=1.0, user-scalable=0">\n    <meta name="referrer" content="origin">\n\n    <title>    Thank you! - NUDE PROJECT - Checkout</title>\n\n      <meta data-browser="" data-browser-major="">\n<meta data-body-font-family="-apple-system, BlinkMacSystemFont, &#39;Segoe UI&#39;, Roboto, Hel
# ...

# %%
def master(url):
    print(requests.get(url))
    threading.current_thread()

# %%
def descargar(x):
